# %%
import pandas as pd

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df = pd.read_csv("data/creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# This counts how many transactions belong to each class.
#
# 0 = normal transactions → 284,315
#
# 1 = fraudulent transactions → 492
#
# Interpretation: There are very few frauds compared to normal transactions.

# %%
df['Class'].value_counts(normalize=True)
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %% [markdown]
# normalize=True shows the proportion (percentage) instead of raw counts.
#
# 0 = 99.83% of all transactions are normal
#
# 1 = 0.17% of all transactions are fraud
#
# Interpretation: Dataset is highly imbalanced → most transactions are normal.

# %% [markdown]
# Why This Matters?
#
# Models trained on imbalanced data may always predict 0 (normal) and still seem “accurate,” but they fail to detect fraud.
#
# For unsupervised anomaly detection, the model tries to learn the normal pattern and flag anything unusual (the 0.17% frauds).

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
# drop duplicates
df=df.drop_duplicates()

# %% [markdown]
# ### Visualize distributions of key features
#
# - For numerical features: Amount and Time
#
# - For fraud vs non-fraud

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of Amount
sns.histplot(df['Amount'], bins=50, kde=True)
plt.title('Transaction Amount Distribution')
plt.show()

# %% [markdown]
# ##### Highly Skewed Distribution
#
# - Most transactions are very small amounts (close to 0).
# - Only a tiny fraction of transactions have very high amounts (up to 25,000).
# - This is called a right-skewed distribution or long tail.
#
# ##### Implications for Fraud Detection
# - Most transactions are small → the model may consider large transactions as potential anomalies.
#
# - High-value transactions are rare → these could be more likely to be fraud, but not always.
#
# - Raw amounts vary widely → scaling or transforming Amount is important before model training.

# %%
# Distribution of Time
sns.histplot(df['Time'], bins=50, kde=True)
plt.title('Transaction Time Distribution')
plt.show()

# %% [markdown]
# ##### Simple Analysis
#
# 1. What's "Normal"?
# The graph shows that people usually make transactions during two main rush hours (the two big hills). This is what our system considers normal activity.
#
# 2. Finding the "Weird" Stuff
# Our fraud detection tool looks for transactions that happen when almost no one else is spending—in the deep valleys (like around Time 100,000) or in the very quiet hours (like early on).
#
# These transactions get a high "weirdness" score because they don't match the normal pattern.
#
# 3. Why Time Matters
# Time is a great clue for fraud. Scammers often strike when the account owner is probably asleep or inactive. On this graph, these "out-of-hours" transactions land in the spots with the lowest activity counts.
#
# The Bottom Line: The plot clearly shows what's typical. If a transaction happens when the graph shows activity is super low, our system will automatically flag it as suspicious for potential fraud.

# %%
# Class distribution plot
sns.countplot(x='Class', data=df)
plt.title('Non-Fraud vs Fraud Transactions')
plt.show()

# %% [markdown]
# This bar plot shows a severe case of class imbalance in the dataset:
#
# 1. Massive Imbalance: The vast majority of transactions belong to Class 0 (Non-Fraud), with a count of nearly 280,000.
#
# 2. Minority Class: The count for Class 1 (Fraud) is extremely low, appearing almost as zero on the scale, which is typical for real-world fraud data.
#
# 3. Modeling Challenge: This imbalance is a major challenge for supervised machine learning models, as they will be highly biased toward predicting the majority class (Non-Fraud), making it hard to correctly identify the rare fraudulent cases.
#
# 4. Implication for Unsupervised Learning: This chart explains why an unsupervised anomaly detection approach is highly suitable, as fraud is treated as a rare outlier (anomaly) rather than a balanced classification problem.

# %% [markdown]
# This is EDA visualization — helps to see skewness, outliers, and class imbalance.

# %% [markdown]
# ##### Check correlations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Copy data
df_corr = df.copy()

# Compute correlation
corr = df_corr.corr()

# Upper & Lower triangular masks
ut = np.triu(np.ones_like(corr, dtype=bool))
lt = np.tril(np.ones_like(corr, dtype=bool))

# Custom color map
colors = "coolwarm"

# Create subplots
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))

# Upper triangular heatmap
sns.heatmap(corr, cmap=colors, annot=False, cbar=True, mask=ut, ax=ax[0])
ax[0].set_title("Correlation Matrix : Upper Triangular Format", fontsize=14)

# Lower triangular heatmap
sns.heatmap(corr, cmap=colors, annot=False, cbar=True, mask=lt, ax=ax[1])
ax[1].set_title("Correlation Matrix : Lower Triangular Format", fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# This image is just two versions of the same map that tells us how much one data feature moves with another.
#
# - Red means strong positive connection: When one feature goes up, the other goes up.
#
# - Blue means strong negative connection: When one feature goes up, the other goes down.
#
# - White/Light Color means no real connection.

# %% [markdown]
# **Key Takeaways**
# - The V Features are Clean: Look at the large white/light areas. This confirms that the important features (V1 through V28) do not overlap or repeat the same information. This is very good for our fraud model.
#
# - Fraud is Hard to Pin Down: Check the row/column labeled Class (Fraud). It is mostly light-colored. This means there is no single feature that perfectly screams "FRAUD!"—it's not as simple as saying "high amount equals fraud." The model needs to look at all the features together.
#
# - Cleaner Display: The triangular format is just a trick to avoid showing the same information twice, making the chart less cluttered.
#
# In short: The data is well-prepared, and it confirms that finding fraud will be subtle—we can't just rely on one simple rule.

# %% [markdown]
# How does the distribution of Amount and Time differ for Class = 0 (non-fraud) vs Class = 1 (fraud)?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Features we want to inspect
features_to_plot = ["Amount", "Time"]  

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

for i, feature in enumerate(features_to_plot):
    sns.boxplot(
        x="Class", 
        y=feature, 
        data=df, 
        ax=axes[i], 
        palette="Set2"
    )
    axes[i].set_title(f"Boxplot of {feature} by Class", fontsize=14)
    axes[i].set_xlabel("Class (0=Non-Fraud, 1=Fraud)")
    axes[i].set_ylabel(feature)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25208\2174720917.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\HP\AppData\Local\Temp\ipykernel_25208\2174720917.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# This figure contains two **boxplots** comparing the distribution of **Amount** and **Time** between non-fraudulent (Class 0) and fraudulent (Class 1) transactions.
#
# ## Boxplot Analysis for Fraud Detection
#
# ### 1. Boxplot of Amount by Class (Left)
#
# * **Non-Fraud (Class 0):** The box is extremely small and close to zero, meaning the **majority of normal transactions are for very small amounts**. The plot is dominated by many **outliers** (the circles above the box) showing some normal transactions can be very large (up to $25,000+).
# * **Fraud (Class 1):** The box is also small and low, but slightly higher than Class 0. This suggests that the typical **fraudulent amount is also small**, though potentially slightly higher on average than normal small transactions.
# * **Key Insight:** Amount, on its own, **doesn't clearly separate** fraud from non-fraud because both classes are skewed toward small values, though the very large non-fraud outliers are important to note.
#
# ### 2. Boxplot of Time by Class (Right)
#
# * **Non-Fraud (Class 0):**
#     * The median (middle line) is around **85,000**.
#     * The box (middle 50% of transactions) is roughly between **55,000 and 140,000**.
#     * This confirms the **bimodal distribution** seen earlier—the total spread covers the two main rush periods.
# * **Fraud (Class 1):**
#     * The median is around **75,000**.
#     * The box is roughly between **40,000 and 125,000**.
# * **Key Insight:** The distributions for Time are **very similar and overlap significantly**. This means a fraudulent transaction is **not likely to be flagged *only* by its time of day**. However, the slightly wider spread for Non-Fraud suggests the *most extreme* early or late transactions might be less common in the small fraud sample.
#
# **In short:**
#
# * **Amount:** Both fraud and non-fraud are mostly small, but normal transactions **sometimes include huge, rare purchases** (massive outliers).
# * **Time:** The time of day **does not strongly differentiate** fraud from non-fraud on a simple median or quartiles basis. Both types of transactions occur across the same typical time periods.

# %% [markdown]
# Outliers exist mostly in Amount. This means we must scale data and rely on multi-feature patterns, not single variables.

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# After handling outliers, the next big step is preprocessing, which usually means scaling  numerical features and (optionally) reducing dimensionality for visualization.
#
# ##### Scale Numerical Features
# We’ll use both MinMaxScaler and StandardScaler to see the difference.

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Select only numerical columns
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns

# Min-Max Scaling (values between 0 and 1)
mms = MinMaxScaler()
df_minmax = df.copy()
df_minmax[numerical_features] = mms.fit_transform(df[numerical_features])

# Standard Scaling (mean = 0, std = 1)
ss = StandardScaler()
df_standard = df.copy()
df_standard[numerical_features] = ss.fit_transform(df[numerical_features])

print("Original Data Sample:\n", df[numerical_features].head())
print("\nMinMax Scaled Data Sample:\n", df_minmax[numerical_features].head())
print("\nStandard Scaled Data Sample:\n", df_standard[numerical_features].head())
# Out:
# Original Data Sample:
#     Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V23       V24       V25       V26       V27  \
# 0  0.098698  0.363787  ... -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1  0.085102 -0.255425  ...  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2  0.247676 -1.514654  ...  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3  0.377436 -1.387024  ... -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4 -0.270533  0.817739  ... -0.137458  0.141267 -0.206010  0.502292  0.219422
#
# ...

# %% [markdown]
# Scaling ensures all features contribute equally to the model, especially if they are on different scales (like Amount vs Time).

# %% [markdown]
# ##### Dimensionality Reduction (Optional for Visualization)
# PCA (Principal Component Analysis)
#
# Reduces to 2D while preserving variance.

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Apply PCA to 2D
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_standard[numerical_features])

# Plot PCA
plt.figure(figsize=(8,6))
plt.scatter(pca_result[:,0], pca_result[:,1], 
            c=df['Class'], cmap='coolwarm', alpha=0.5)
plt.title("PCA - Fraud vs Non-Fraud (2D)")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()

# %% [markdown]
# t-SNE (for more non-linear separation)
#
# Better at visualizing clusters but heavier to run.

# %%
from sklearn.manifold import TSNE

# Apply t-SNE (only on a subset if data is huge)
tsne = TSNE(n_components=2, random_state=42, perplexity=30, max_iter=500)  # use max_iter
tsne_result = tsne.fit_transform(df_standard[numerical_features][:5000])  # sample 5k rows

# Plot t-SNE
plt.figure(figsize=(8,6))
plt.scatter(tsne_result[:,0], tsne_result[:,1], 
            c=df['Class'][:5000], cmap='coolwarm', alpha=0.5)
plt.title("t-SNE - Fraud vs Non-Fraud (2D)")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.show()

# %% [markdown]
# ### Unsupervised Techniques
#
# Isolation Forest
#
# One-Class SVM
#
# Autoencoder (more advanced)

# %%
# Isolation Forest
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report, confusion_matrix

# Define model
iso_forest = IsolationForest(
    n_estimators=100,          # number of trees
    contamination=0.0017,      # fraction of frauds (Class 1)
    random_state=42
)

# Fit model on all numerical features
iso_forest.fit(df_standard[numerical_features])

# Predict anomalies: -1 = anomaly, 1 = normal
df['iso_pred'] = iso_forest.predict(df_standard[numerical_features])
df['iso_pred'] = df['iso_pred'].map({1:0, -1:1})  # convert to 0=normal, 1=fraud

# Evaluation
print("Confusion Matrix:\n", confusion_matrix(df['Class'], df['iso_pred']))
print("\nClassification Report:\n", classification_report(df['Class'], df['iso_pred']))
# Out:
# Confusion Matrix:
#  [[282857    396]
#  [   386     87]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    283253
#            1       0.18      0.18      0.18       473
#
#     accuracy                           1.00    283726
#    macro avg       0.59      0.59      0.59    283726
# weighted avg       1.00      1.00      1.00    283726
# C:\Users\HP\AppData\Local\Temp\ipykernel_25208\505516599.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['iso_pred'] = iso_forest.predict(df_standard[numerical_features])
# C:\Users\HP\AppData\Local\Temp\ipykernel_25208\505516599.py:17: SettingWithCopyWarning:
# ...

# %% [markdown]
# Model Predicted	Actual                   Non-Fraud (0)	                Actual Fraud (1)
#
# Predicted Non-Fraud (0)	             282,857 (Correct)	              386 (BAD Misses - FN)
#
# Predicted Fraud (1)	                 396 (False Alarms - FP)          	87 (Caught Fraud - TP)

# %% [markdown]
# **Simple Summary of Isolation Forest Results**
#
# 1. The Confusion Matrix (What Happened)
#
# Model Predicted	Actual Non-Fraud (0)	Actual Fraud (1)
#
# Predicted Non-Fraud (0)	282,857 (Correct)	386 (BAD Misses - FN)
#
# Predicted Fraud (1)	396 (False Alarms - FP)	87 (Caught Fraud - TP)
#
# 2. The Main Problem: Missing Fraud
# The biggest issue is the Recall for Fraud (Class 1) is only 0.18 (18%).
#
# This means the model missed 82% of all actual fraud cases (386 out of 473 total fraud transactions).
#
# A fraud detection system that misses most of the fraud is not useful.
#
# 3. Misleading High Score
# The overall Accuracy is 1.00, but this score is useless here.
#
# The model achieved this score simply by being excellent at predicting the 99.8% of transactions that are not fraud.
#
# In fraud detection, ignore the high overall accuracy and focus only on the fraud metrics (Recall/Precision).

# %% [markdown]
# #### One-Class SVM

# %%
from sklearn.svm import OneClassSVM

# Define model
oc_svm = OneClassSVM(
    kernel='rbf', 
    gamma='auto', 
    nu=0.0017   # fraction of anomalies expected
)

# Fit model
oc_svm.fit(df_standard[numerical_features])

# Predict anomalies: -1 = anomaly, 1 = normal
df['svm_pred'] = oc_svm.predict(df_standard[numerical_features])
df['svm_pred'] = df['svm_pred'].map({1:0, -1:1})  # convert to 0=normal, 1=fraud

# Evaluation
print("Confusion Matrix:\n", confusion_matrix(df['Class'], df['svm_pred']))
print("\nClassification Report:\n", classification_report(df['Class'], df['svm_pred']))
# Out:
# Confusion Matrix:
#  [[281993   1260]
#  [   338    135]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    283253
#            1       0.10      0.29      0.14       473
#
#     accuracy                           0.99    283726
#    macro avg       0.55      0.64      0.57    283726
# weighted avg       1.00      0.99      1.00    283726
# C:\Users\HP\AppData\Local\Temp\ipykernel_25208\1745511759.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['svm_pred'] = oc_svm.predict(df_standard[numerical_features])
# C:\Users\HP\AppData\Local\Temp\ipykernel_25208\1745511759.py:15: SettingWithCopyWarning:
# ...

# %% [markdown]
# The model has a better ability to catch fraud (Recall) but now has a much higher rate of false alarms (Lower Precision).
#
# 1. Confusion Matrix Breakdown
# The matrix shows the raw counts for the two classes:
#
# Metric	Count	Interpretation
# Caught Fraud (TP)	135	The model correctly identified 135 actual fraud cases. (Improved)
# Missed Fraud (FN)	338	The model failed to flag 338 actual fraud cases.
# False Alarms (FP)	1,260	Non-fraud transactions were mistakenly flagged as fraud. (Worse)
# True Negatives (TN)	281,993	Correctly identified non-fraud.
#
#
# 2. Classification Report: Focus on Fraud (Class 1)
# Metric	Value	Interpretation
# Recall	0.29 (29%)	The model caught 29% of all the real fraud cases (135 out of 473). This is better than the previous model's 18% recall.
# Precision	0.10 (10%)	Out of everything the model flagged as fraud (1260+135=1395), only 10% was actually fraud. This is much worse than before. The model now generates many false alarms (1,260 FPs).
# F1-Score	0.14	A low score that reflects the poor trade-off between Recall and Precision.
#
# This model shows the classic trade-off in anomaly detection:
#
# - Positive: The model is more sensitive and catches more fraud (Higher Recall).
#
# - Negative: This comes at the cost of many more false alarms (Low Precision). Flagging 1,260 non-fraud transactions as fraud is a significant operational burden (e.g., stopping customer transactions).
#
# The goal should be to find a sweet spot where Recall is high enough to be useful (ideally >50%), and Precision is high enough to minimize customer disruption. This version is still not effective due to the extremely low Precision.

# %%
import pandas as pd

results_summary = pd.DataFrame({
    'Model': ['Isolation Forest', 'One-Class SVM'],  # add 'Autoencoder' if used
    'Precision (Fraud)': [
        0.18,  # from Isolation Forest report
        0.10   # from One-Class SVM report
    ],
    'Recall (Fraud)': [
        0.18,
        0.29
    ],
    'F1-score (Fraud)': [
        0.18,
        0.14
    ],
    'Detected Frauds': [
        df['iso_pred'].sum(),
        df['svm_pred'].sum()
    ]
})

print(results_summary)
# Out:
#               Model  Precision (Fraud)  Recall (Fraud)  F1-score (Fraud)  \
# 0  Isolation Forest               0.18            0.18              0.18
# 1     One-Class SVM               0.10            0.29              0.14
#
#    Detected Frauds
# 0              483
# 1             1395

# %% [markdown]
# Visualize Fraud Detection
# A plot can make the comparison clear:

# %%
import matplotlib.pyplot as plt

# Bar plot of detected frauds
plt.figure(figsize=(8,5))
plt.bar(results_summary['Model'], results_summary['Detected Frauds'], color=['skyblue','salmon'])
plt.ylabel("Number of Detected Frauds")
plt.title("Comparison of Detected Frauds by Model")
plt.show()

# %% [markdown]
# Based on the provided bar chart and metrics, the choice between the two models depends on your priority:
#
# Metric	Isolation Forest	One-Class SVM	Better Model	Rationale
# Precision	0.18 (18%)	0.10 (10%)	Isolation Forest	Better at keeping False Alarms (FP) low. If you want fewer wrongly flagged customers, choose this.
# Recall	0.18 (18%)	0.29 (29%)	One-Class SVM	Better at catching actual fraud (TP). If minimizing fraud loss is your top priority, choose this.
# Detected Frauds (Flagged Total)	483	1395	(N/A)	SVM flags nearly 3 times more transactions as fraud than Isolation Forest.
#
# Export to Sheets
# Conclusion
# One-Class SVM (The Bar on the Right) is BETTER at detection (Recall), catching 29% of all fraud cases. However, it comes with a high cost: most of its flags are wrong (Precision is only 10%).
#
# Isolation Forest (The Bar on the Left) is CLEANER (Precision), as its predictions are more accurate (18%), but it misses more fraud (Recall is only 18%).
#
# Neither model is truly good, but the One-Class SVM is often preferred in the initial phases of fraud detection because it maximizes Recall, despite the high number of false alarms.

# %%
# Example: false positives for Isolation Forest
fp_iso = confusion_matrix(df['Class'], df['iso_pred'])[0][1]
print(f"Isolation Forest False Positives: {fp_iso}")
# Out:
# Isolation Forest False Positives: 396

# %% [markdown]
# Optional: ROC-AUC Curve
#
# Even unsupervised models can be evaluated with ROC-AUC using the predicted anomaly scores:

# %%
from sklearn.metrics import roc_auc_score

# Isolation Forest anomaly score (-1 = anomaly)
iso_scores = -iso_forest.decision_function(df_standard[numerical_features])  # higher = more likely fraud
roc_auc_iso = roc_auc_score(df['Class'], iso_scores)
print("ROC-AUC (Isolation Forest):", roc_auc_iso)
# Out:
# ROC-AUC (Isolation Forest): 0.9568637526918556

# %% [markdown]
# The ROC-AUC (Receiver Operating Characteristic - Area Under the Curve) value of 0.95686 for the Isolation Forest model is a measure of its overall performance and separability of the two classes (Fraud and Non-Fraud).
#
# In simple terms:
#
# It's very good: A score of 1.0 is perfect, and 0.5 is random guessing. A score of 0.956 is excellent and very close to perfect.
#
# Separability: It means the model is highly capable of distinguishing between a random fraud transaction and a random non-fraud transaction. If you randomly pick one of each, the model's anomaly score for the fraud case will be higher than the score for the non-fraud case approximately 95.68% of the time.

# %% [markdown]
# Identify flagged transactions
#
# For each model, see which transactions were flagged:

# %%
# Isolation Forest
flagged_iso = df[df['iso_pred'] == 1]
print("Isolation Forest - Flagged transactions:\n", flagged_iso.head())

# One-Class SVM
flagged_svm = df[df['svm_pred'] == 1]
print("\nOne-Class SVM - Flagged transactions:\n", flagged_svm.head())
# Out:
# Isolation Forest - Flagged transactions:
#          Time         V1         V2         V3        V4         V5         V6  \
# 164    103.0  -6.093248 -12.114213  -5.694973  3.294389  -1.413792   4.776000
# 1632  1264.0 -11.140706  -9.612726 -12.389545  6.013346 -32.092129  21.393069
# 2963  2507.0  -6.200114   5.025406  -2.742492 -0.940903  -6.656259   5.432294
# 5425  5406.0  -8.733429  -5.681953   2.253879  3.930311  -0.916149   4.355297
# 6783  8544.0  -6.571336 -11.943892  -4.246322  6.825816  -2.896624   2.706661
#
#              V7         V8        V9  ...       V25       V26       V27  \
# 164    4.808426  -0.228197 -0.525896  ... -0.406073 -0.653384 -0.711222
# 1632  34.303177  -7.520784 -1.925732  ...  0.746267  0.801387  3.852046
# 2963  -9.198175 -22.588547 -3.244295  ... -1.343379 -0.707634 -0.210219
# 5425   5.400286  -4.994383  6.819787  ... -0.029485 -0.264455 -7.976100
# 6783   5.373923  -0.872187 -0.626203  ... -0.740824 -0.297883 -0.793710
#
# ...

# %% [markdown]
# Compare with actual frauds
#
# Check how many flagged transactions were actually fraud:

# %%
# Isolation Forest
true_frauds_iso = flagged_iso['Class'].sum()
total_flagged_iso = len(flagged_iso)
print(f"Isolation Forest detected {true_frauds_iso}/{total_flagged_iso} flagged transactions correctly as fraud.")

# One-Class SVM
true_frauds_svm = flagged_svm['Class'].sum()
total_flagged_svm = len(flagged_svm)
print(f"One-Class SVM detected {true_frauds_svm}/{total_flagged_svm} flagged transactions correctly as fraud.")
# Out:
# Isolation Forest detected 87/483 flagged transactions correctly as fraud.
# One-Class SVM detected 135/1395 flagged transactions correctly as fraud.

# %% [markdown]
# Analyze patterns in detected anomalies
#
# Look at key numerical features like Amount and Time:

# %%
# Distribution of Amount for flagged transactions
plt.figure(figsize=(12,5))
sns.histplot(flagged_iso['Amount'], bins=50, color='salmon', kde=True)
plt.title("Isolation Forest - Transaction Amount for Flagged Anomalies")
plt.xlabel("Amount")
plt.show()

# Distribution of Time for flagged transactions
plt.figure(figsize=(12,5))
sns.histplot(flagged_iso['Time'], bins=50, color='skyblue', kde=True)
plt.title("Isolation Forest - Transaction Time for Flagged Anomalies")
plt.xlabel("Time")
plt.show()

# %% [markdown]
# Correlation or PCA for flagged transactions

# %%
# PCA of flagged transactions
from sklearn.decomposition import PCA

pca_flagged = PCA(n_components=2)
pca_result = pca_flagged.fit_transform(flagged_iso[numerical_features])

plt.figure(figsize=(8,6))
plt.scatter(pca_result[:,0], pca_result[:,1], 
            c=flagged_iso['Class'], cmap='coolwarm', alpha=0.5)
plt.title("PCA - Flagged Transactions (Red=Fraud, Blue=Non-Fraud)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %% [markdown]
# ## **Final Project Conclusion and Key Takeaways**
#
# ### **Conclusion: Strong Potential, Current Limitations ⚠️**
#
# The project confirms that **credit card fraud is extremely rare and complex** (only 0.17% of transactions). Using unsupervised models like **Isolation Forest** and **One-Class SVM**, we successfully identified anomalies that often occur on the outer edges of the data space.
#
# However, **performance on the fraud class remains insufficient for real-world deployment**:
#
# * **Isolation Forest**
#
#   * **Recall:** 18% → misses 82% of actual fraud cases
#   * **ROC-AUC:** 0.956 → shows the model has strong potential to separate fraud from normal transactions
#   * **Strength:** Fewer false alarms, more precise predictions
#   * **Weakness:** Misses most fraud cases
#
# * **One-Class SVM**
#
#   * **Precision:** 10% → 90% of flagged transactions are false alarms
#   * **Recall:** 29% → catches more fraud than Isolation Forest
#   * **Strength:** Detects more actual frauds
#   * **Weakness:** Generates a high number of false positives, creating operational burden
#
# ### **Key Takeaways**
#
# 1. **Fraud detection is challenging** — single features like `Amount` or `Time` are insufficient. Multivariate anomaly detection is required.
# 2. **Isolation Forest shows strong inherent potential**, as indicated by the ROC-AUC, but needs **better tuning and calibration**.
# 3. **Model selection depends on priorities**:
#
#    * Minimize missed fraud → prioritize recall (One-Class SVM)
#    * Minimize false alarms → prioritize precision (Isolation Forest)
# 4. **Next steps**:
#
#    * Tune hyperparameters to improve Recall and Precision balance
#    * Explore **ensemble or hybrid models** (e.g., combining Isolation Forest, One-Class SVM, and Autoencoders)
#    * Consider additional preprocessing or feature engineering to highlight fraud patterns
#
# > **Bottom line:** The project validates the approach and confirms that unsupervised models can detect anomalies, but **further optimization is required for reliable fraud detection in practice**.
